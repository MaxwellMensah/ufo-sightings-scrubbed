# %%
# %matplotlib inline
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("ufo-sightings-scrubbed.csv")
df
# Out:
# C:\Users\Max_m\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# ...

# %%
ufo = df

# %%
df.isnull().sum()
# Out:
# datetime                   0
# city                       0
# state                   5797
# country                 9670
# shape                   1932
# duration (seconds)         0
# duration (hours/min)       0
# comments                  15
# date posted                0
# latitude                   0
# longitude                  0
# dtype: int64

# %%
df
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min) date posted    latitude  \
# ...

# %%
df1 = df.drop('duration (hours/min)', axis=1)

# %%
df.isnull().sum()
# Out:
# datetime                   0
# city                       0
# state                   5797
# country                 9670
# shape                   1932
# duration (seconds)         0
# duration (hours/min)       0
# date posted                0
# latitude                   0
# longitude                  0
# dtype: int64

# %%
print(df['country'][4:55])
# Out:
# 4      us
# 5      us
# 6      gb
# 7      us
# 8      us
# 9      us
# 10     us
# 11     us
# 12     us
# 13     us
# 14     us
# 15     us
# 16     us
# 17     us
# 18    NaN
# 19     us
# 20     gb
# 21     us
# 22     us
# 23     us
# 24     gb
# 25     us
# 26     us
# 27     us
# 28     us
# 29    NaN
# 30     us
# 31     us
# 32     us
# 33     us
# 34     us
# 35    NaN
# 36     us
# 37     us
# 38     us
# 39     gb
# 40    NaN
# 41     us
# 42     us
# 43     us
# 44     us
# 45     us
# 46     us
# 47    NaN
# 48     us
# 49     us
# 50     us
# 51     us
# 52     us
# 53     us
# 54     us
# Name: country, dtype: object

# %%
df1.head(10)
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
# 5  10/10/1961 19:00               bristol    tn      us    sphere
# 6  10/10/1965 21:00    penarth (uk/wales)   NaN      gb    circle
# 7  10/10/1965 23:45               norwalk    ct      us      disk
# 8  10/10/1966 20:00             pell city    al      us      disk
# 9  10/10/1966 21:00              live oak    fl      us      disk
#
#   duration (seconds) date posted    latitude  longitude
# 0               2700   4/27/2004  29.8830556  -97.941111
# 1               7200  12/16/2005    29.38421  -98.581082
# 2                 20   1/21/2008        53.2   -2.916667
# ...

# %%
df2 = df1.dropna()

# %%
df2.isnull().sum()
# Out:
# datetime              0
# city                  0
# state                 0
# country               0
# shape                 0
# duration (seconds)    0
# date posted           0
# latitude              0
# longitude             0
# dtype: int64

# %%
df2.isnull()
# Out:
#        datetime   city  state  country  shape  duration (seconds)  \
# 0         False  False  False    False  False               False
# 3         False  False  False    False  False               False
# 4         False  False  False    False  False               False
# 5         False  False  False    False  False               False
# 7         False  False  False    False  False               False
# ...         ...    ...    ...      ...    ...                 ...
# 80327     False  False  False    False  False               False
# 80328     False  False  False    False  False               False
# 80329     False  False  False    False  False               False
# 80330     False  False  False    False  False               False
# 80331     False  False  False    False  False               False
#
#        date posted  latitude  longitude
# 0            False     False       False
# 3            False     False       False
# 4            False     False       False
# ...

# %%
# Now our dataset is clean

# %% [markdown]
# ### Setting the dataset index to datetime

# %%
df3 = df2.set_index("datetime")

# %%
df3.head()
# Out:
#                         city state country     shape duration (seconds)  \
# datetime
# 10/10/1949 20:30  san marcos    tx      us  cylinder               2700
# 10/10/1956 21:00        edna    tx      us    circle                 20
# 10/10/1960 20:00     kaneohe    hi      us     light                900
# 10/10/1961 19:00     bristol    tn      us    sphere                300
# 10/10/1965 23:45     norwalk    ct      us      disk               1200
#
#                  date posted    latitude  longitude
# datetime
# 10/10/1949 20:30   4/27/2004  29.8830556  -97.941111
# 10/10/1956 21:00   1/17/2004  28.9783333  -96.645833
# 10/10/1960 20:00   1/22/2004  21.4180556 -157.803611
# 10/10/1961 19:00   4/27/2007  36.5950000  -82.188889
# 10/10/1965 23:45   10/2/1999  41.1175000  -73.408333

# %%
# We visualize our dataset
